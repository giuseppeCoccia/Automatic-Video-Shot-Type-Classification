# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
def read_csv(filename):
    losses, train_accs, valid_accs = [], [], []
    
    with open(filename, newline='') as csvfile:
        reader = csv.reader(csvfile, delimiter=';', quotechar='|')
        next(reader, None)
        for row in reader:
            losses.append(float(row[0]))
            train_accs.append(float(row[1]))
            valid_accs.append(float(row[2]))
        
    return losses, train_accs, valid_accs

def plot_loss(losses, title):
    plt.figure(figsize=(23, 5))
    plt.grid()
    plt.xticks(range(0, len(losses), 5))
    plt.title(title)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.xlim(0, len(losses)-1)
    plt.plot(range(len(losses)), losses)
    
def plot_train_valid_accuracy(train_accs, valid_accs, title):
    plt.figure(figsize=(23, 5))
    plt.grid()
    plt.xticks(range(0, len(losses), 5))
    plt.title(title)
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.xlim(0, len(losses)-1)
    plt.plot(range(len(train_accs)), train_accs, label="Train_accuracy")
    plt.plot(range(len(valid_accs)), valid_accs, label="Validation_accuracy")
    plt.legend()

# %% [markdown]
# # 1. ResNet

# %% [markdown]
# ## 1.1 Tanh features transformation

# %%
losses, train_accs, valid_accs = read_csv("out_tanh_0.01lr.csv")
plot_loss(losses, "Loss on ResNet with learning_rate=0.01 and tanh as features transformation")
plot_train_valid_accuracy(train_accs, valid_accs, "Accuracy on ResNet with learning_rate=0.01 and tanh as features transformation")

# %%
losses, train_accs, valid_accs = read_csv("out_tanh_0.001lr.csv")
plot_loss(losses, "Loss on ResNet with learning_rate=0.001 and tanh as features transformation")
plot_train_valid_accuracy(train_accs, valid_accs, "Accuracy on ResNet with learning_rate=0.001 and tanh as features transformation")

# %%
losses, train_accs, valid_accs = read_csv("out_tanh_0.0001lr.csv")
plot_loss(losses, "Loss on ResNet with learning_rate=0.0001 and tanh as features transformation")
plot_train_valid_accuracy(train_accs, valid_accs, "Accuracy on ResNet with learning_rate=0.0001 and tanh as features transformation")

# %% [markdown]
# ## 1.1 Log1p features transformation

# %%
losses, train_accs, valid_accs = read_csv("out_log1p_0.01lr.csv")
plot_loss(losses, "Loss on ResNet with learning_rate=0.01 and log1p as features transformation")
plot_train_valid_accuracy(train_accs, valid_accs, "Accuracy on ResNet with learning_rate=0.01 and log1p as features transformation")

# %%
losses, train_accs, valid_accs = read_csv("out_log1p_0.001lr.csv")
plot_loss(losses, "Loss on ResNet with learning_rate=0.001 and log1p as features transformation")
plot_train_valid_accuracy(train_accs, valid_accs, "Accuracy on ResNet with learning_rate=0.001 and log1p as features transformation")

# %%
losses, train_accs, valid_accs = read_csv("out_log1p_0.0001lr.csv")
plot_loss(losses, "Loss on ResNet with learning_rate=0.0001 and log1p as features transformation")
plot_train_valid_accuracy(train_accs, valid_accs, "Accuracy on ResNet with learning_rate=0.0001 and log1p as features transformation")

# %% [markdown]
# ## 1.2 100 epochs models: tanh, 0.001 lr

# %%
losses, train_accs, valid_accs = read_csv("resnet_out_tanh_0.0001lr_100e_models.csv")
plot_loss(losses, "Loss on ResNet with learning_rate=0.0001 and tanh as features transformation")
plot_train_valid_accuracy(train_accs, valid_accs, "Accuracy on ResNet with learning_rate=0.0001 and tanh as features transformation")

# %%
losses, train_accs, valid_accs = read_csv("resnet_out_tanh_0.00001lr_m98.csv")
plot_loss(losses, "Loss on ResNet with learning_rate=0.00001 and tanh as features transformation, 100 epochs, starting at iter 98")
plot_train_valid_accuracy(train_accs, valid_accs, "Accuracy on ResNet with learning_rate=0.00001 and tanh as features transformation, 100 epochs, start at 98e")

# %%
losses, train_accs, valid_accs = read_csv("resnet_out_tanh_0.0001lr_300e.csv")
plot_loss(losses, "Loss on ResNet with learning_rate=0.0001 and tanh as features transformation, 300 epochs")
plot_train_valid_accuracy(train_accs, valid_accs, "Accuracy on ResNet with learning_rate=0.0001 and tanh as features transformation, 300 epochs")

# %% [markdown]
# # 2. LeNet

# %%
losses, train_accs, valid_accs = read_csv("lenet_out_0.01lr.csv")
plot_loss(losses, "Loss on LeNet with learning_rate=0.01")
plot_train_valid_accuracy(train_accs, valid_accs, "Accuracy on LeNet with learning_rate=0.01")

# %%
losses, train_accs, valid_accs = read_csv("lenet_out_0.001lr.csv")
plot_loss(losses, "Loss on LeNet with learning_rate=0.001")
plot_train_valid_accuracy(train_accs, valid_accs, "Accuracy on LeNet with learning_rate=0.001")

# %%
losses, train_accs, valid_accs = read_csv("lenet_out_0.0001lr.csv")
plot_loss(losses, "Loss on LeNet with learning_rate=0.0001")
plot_train_valid_accuracy(train_accs, valid_accs, "Accuracy on LeNet with learning_rate=0.0001")

# %% [markdown]
# # 3. Shallow CNN

# %%
losses, train_accs, valid_accs = read_csv("scnn_out_0.01lr.csv")
plot_loss(losses, "Loss on SCNN with learning_rate=0.01")
plot_train_valid_accuracy(train_accs, valid_accs, "Accuracy on SCNN with learning_rate=0.01")

# %%
losses, train_accs, valid_accs = read_csv("scnn_out_0.001lr.csv")
plot_loss(losses, "Loss on SCNN with learning_rate=0.001")
plot_train_valid_accuracy(train_accs, valid_accs, "Accuracy on SCNN with learning_rate=0.001")

# %%
losses, train_accs, valid_accs = read_csv("scnn_out_0.0001lr.csv")
plot_loss(losses, "Loss on SCNN with learning_rate=0.0001")
plot_train_valid_accuracy(train_accs, valid_accs, "Accuracy on SCNN with learning_rate=0.0001")
